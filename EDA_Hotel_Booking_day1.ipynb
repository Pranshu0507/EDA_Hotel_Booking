# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranshu0507/EDA_Hotel_Booking/blob/main/EDA_Hotel_Booking_day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
>>> s = pd.Series([1, 3, 2])
>>> s.plot.line()
# Out:
# <Axes: >

# %%
>>> df = pd.DataFrame({
...    'pig': [20, 18, 489, 675, 1776],
...    'horse': [4, 25, 281, 600, 1900]
...    }, index=[1990, 1997, 2003, 2009, 2014])
>>> lines = df.plot.line()
